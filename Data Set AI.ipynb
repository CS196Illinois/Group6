# %%
import datasets

# %%
ai = datasets.load_dataset("ai2_arc", 'ARC-Easy')
# Out:
# ...
# Dataset ai2_arc downloaded and prepared to /home/reality/.cache/huggingface/datasets/ai2_arc/ARC-Easy/1.0.0/003a2177b3a283c4d08b9fde4b4de75372e73fb3fdbbf7e1d151398fc9fdcdde. Subsequent calls will reuse this data.

# %%
for x in ai.items():
    print(x)
# Out:
# ('train', Dataset(features: {'id': Value(dtype='string', id=None), 'question': Value(dtype='string', id=None), 'choices': Sequence(feature={'text': Value(dtype='string', id=None), 'label': Value(dtype='string', id=None)}, length=-1, id=None), 'answerKey': Value(dtype='string', id=None)}, num_rows: 2251))
# ('test', Dataset(features: {'id': Value(dtype='string', id=None), 'question': Value(dtype='string', id=None), 'choices': Sequence(feature={'text': Value(dtype='string', id=None), 'label': Value(dtype='string', id=None)}, length=-1, id=None), 'answerKey': Value(dtype='string', id=None)}, num_rows: 2376))
# ('validation', Dataset(features: {'id': Value(dtype='string', id=None), 'question': Value(dtype='string', id=None), 'choices': Sequence(feature={'text': Value(dtype='string', id=None), 'label': Value(dtype='string', id=None)}, length=-1, id=None), 'answerKey': Value(dtype='string', id=None)}, num_rows: 570))

# %%
ai['train']
# Out:
# Dataset(features: {'id': Value(dtype='string', id=None), 'question': Value(dtype='string', id=None), 'choices': Sequence(feature={'text': Value(dtype='string', id=None), 'label': Value(dtype='string', id=None)}, length=-1, id=None), 'answerKey': Value(dtype='string', id=None)}, num_rows: 2251)

# %%
for i in range(len(ai['train'])):
    print(ai['train'][i])
# Out:
# {'answerKey': 'B', 'choices': {'label': ['A', 'B', 'C', 'D'], 'text': ['a leg muscle relaxing after exercise', 'a bacterial population in the bloodstream', 'several viral particles on the skin', 'carbohydrates being digested in the stomach']}, 'id': 'Mercury_7220990', 'question': 'Which factor will most likely cause a person to develop a fever?'}
# {'answerKey': 'B', 'choices': {'label': ['A', 'B', 'C', 'D'], 'text': ['carbon dioxide', 'food', 'protection', 'water']}, 'id': 'MCAS_2007_8_5189', 'question': 'Lichens are symbiotic organisms made of green algae and fungi. What do the green algae supply to the fungi in this symbiotic relationship?'}
# {'answerKey': 'D', 'choices': {'label': ['A', 'B', 'C', 'D'], 'text': ['cause the charge to build.', 'increase and decrease the voltage.', 'cause the current to change direction.', 'stop and start the flow of current.']}, 'id': 'Mercury_SC_401169', 'question': 'When a switch is used in an electrical circuit, the switch can'}
# ...
